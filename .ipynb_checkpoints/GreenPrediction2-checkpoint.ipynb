# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# Load the dataset
data = pd.read_csv('EAE_Data.csv', parse_dates=['timestamp'], index_col='timestamp')

# Drop the unnecessary columns
data = data.drop(columns=['cpu-energy', 'memory-energy'])

# Fill missing values
data.fillna(method='ffill', inplace=True)

# Normalize the data
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data)

# Convert to DataFrame
scaled_df = pd.DataFrame(scaled_data, columns=data.columns, index=data.index)

# Create the lagged dataset for supervised learning
def create_lagged_dataset(df, n_lags=1):
    X, y = [], []
    for i in range(n_lags, len(df)):
        X.append(df.iloc[i-n_lags:i].values)
        y.append(df.iloc[i].values)
    return np.array(X), np.array(y)

# Define the number of lag steps
n_lags = 10

# Create the dataset
X, y = create_lagged_dataset(scaled_df, n_lags)

# Split the data into training and testing sets
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 5
#       3 from sklearn.preprocessing import MinMaxScaler
#       4 import matplotlib.pyplot as plt
# ----> 5 from tensorflow.keras.models import Sequential
#       6 from tensorflow.keras.layers import LSTM, Dense
#       8 # Load the dataset
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
# Define the LSTM model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(LSTM(units=50))
model.add(Dense(units=3))  # We have 3 features to predict: cpu, memory, sci-e

model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.2)
# Out:
# C:\Users\045sh\Documents\Fuzz\Anaconda\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/20
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - loss: 0.0351 - val_loss: 0.0337
# Epoch 2/20
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0311 - val_loss: 0.0336
# Epoch 3/20
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0313 - val_loss: 0.0336
# Epoch 4/20
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0321 - val_loss: 0.0337
# Epoch 5/20
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0341 - val_loss: 0.0337
# Epoch 6/20
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0319 - val_loss: 0.0336
# Epoch 7/20
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0334 - val_loss: 0.0336
# Epoch 8/20
# ...

# %%
# Function to predict future values
def predict_future(model, data, n_steps):
    prediction_list = data[-n_lags:]
    for _ in range(n_steps):
        x = prediction_list[-n_lags:]
        x = x.reshape((1, n_lags, data.shape[1]))
        out = model.predict(x)[0]
        prediction_list = np.append(prediction_list, out.reshape(1, -1), axis=0)
    return prediction_list[n_lags:]

# Predict the next 300 data points
future_predictions = predict_future(model, scaled_df.values, 300)

# Inverse transform the predictions to original scale
future_predictions_inv = scaler.inverse_transform(future_predictions)

# Convert predictions to DataFrame
future_predictions_df = pd.DataFrame(future_predictions_inv, columns=['cpu', 'memory', 'sci-e'])

# Generate timestamps for future predictions
last_timestamp = data.index[-1]
future_timestamps = pd.date_range(start=last_timestamp, periods=300, freq='S')
future_predictions_df['timestamp'] = future_timestamps
future_predictions_df.set_index('timestamp', inplace=True)

print(future_predictions_df)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# ...

# %%
# Predict on the test set
y_pred = model.predict(X_test)

# Inverse transform the predictions and the actual values to original scale
y_pred_inv = scaler.inverse_transform(y_pred)
y_test_inv = scaler.inverse_transform(y_test)

# Calculate RMSE for each feature
rmse_cpu = np.sqrt(np.mean((y_test_inv[:, 0] - y_pred_inv[:, 0])**2))
rmse_memory = np.sqrt(np.mean((y_test_inv[:, 1] - y_pred_inv[:, 1])**2))
rmse_sci_e = np.sqrt(np.mean((y_test_inv[:, 2] - y_pred_inv[:, 2])**2))

print(f'RMSE (CPU): {rmse_cpu}')
print(f'RMSE (Memory): {rmse_memory}')
print(f'RMSE (SCI-E): {rmse_sci_e}')

# Plot predictions vs actual values for visual inspection
plt.figure(figsize=(14, 8))
plt.plot(y_test_inv[:, 0], label='Actual CPU')
plt.plot(y_pred_inv[:, 0], label='Predicted CPU')
plt.legend()
plt.show()

plt.figure(figsize=(14, 8))
plt.plot(y_test_inv[:, 1], label='Actual Memory')
plt.plot(y_pred_inv[:, 1], label='Predicted Memory')
plt.legend()
plt.show()

plt.figure(figsize=(14, 8))
plt.plot(y_test_inv[:, 2], label='Actual SCI-E')
plt.plot(y_pred_inv[:, 2], label='Predicted SCI-E')
plt.legend()
plt.show()
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# RMSE (CPU): 0.011744060810810716
# RMSE (Memory): 0.00039037492199052904
# RMSE (SCI-E): 5.628745523953613e-08

# %%
model.save('time_series_model_2.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
