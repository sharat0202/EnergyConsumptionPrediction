# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# Load the dataset
data = pd.read_csv('EAE_Data.csv', parse_dates=['timestamp'], index_col='timestamp')

# Handle missing values
data.fillna(method='ffill', inplace=True)

# Normalize the data
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data)

# Convert to DataFrame
scaled_df = pd.DataFrame(scaled_data, columns=data.columns, index=data.index)

# %%
scaled_df.head(5)
# Out:
#                           cpu    memory  cpu-energy  memory-energy     sci-e
# timestamp
# 2024-07-30 14:06:54  0.079366  0.089476    0.079367       0.089476  0.086606
# 2024-07-30 14:06:55  0.079907  0.089476    0.079908       0.089476  0.086616
# 2024-07-30 14:06:55  0.079348  0.089476    0.079349       0.089476  0.086605
# 2024-07-30 14:06:55  0.078939  0.089476    0.078940       0.089476  0.086598
# 2024-07-30 14:06:55  0.050022  0.089476    0.050022       0.089476  0.086053

# %%
# Plot the data
plt.figure(figsize=(14, 8))
for column in scaled_df.columns:
    plt.plot(scaled_df.index, scaled_df[column], label=column)
plt.legend()
plt.show()

# %%
scaled_df=scaled_df.drop(columns=['cpu-energy','memory-energy'])

# %%
def create_lag_features(df, lag=1):
    for col in df.columns:
        for i in range(1, lag + 1):
            df[f'{col}_lag_{i}'] = df[col].shift(i)
    df.dropna(inplace=True)
    return df

lagged_df = create_lag_features(scaled_df, lag=3)

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# Define the target variable and features
X = lagged_df.drop(columns=['cpu', 'memory', 'sci-e'])
y = lagged_df[['cpu','memory','sci-e']]

train_size = int(len(lagged_df) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Reshape data for LSTM [samples, timesteps, features]
X_train = X_train.values.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = X_test.values.reshape((X_test.shape[0], 1, X_test.shape[1]))
y_train = y_train.values
y_test = y_test.values

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# Build the LSTM model
model = Sequential()
model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(3))  # Output layer for cpu, memory, sci-e

model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), verbose=2, shuffle=False)
# Out:
# C:\Users\045sh\Documents\Fuzz\Anaconda\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 180/180 - 7s - 37ms/step - loss: 0.0346 - val_loss: 0.0064
# Epoch 2/50
# 180/180 - 1s - 5ms/step - loss: 0.0336 - val_loss: 0.0054
# Epoch 3/50
# 180/180 - 1s - 4ms/step - loss: 0.0334 - val_loss: 0.0047
# Epoch 4/50
# 180/180 - 1s - 4ms/step - loss: 0.0333 - val_loss: 0.0043
# Epoch 5/50
# 180/180 - 1s - 4ms/step - loss: 0.0332 - val_loss: 0.0042
# Epoch 6/50
# 180/180 - 1s - 8ms/step - loss: 0.0332 - val_loss: 0.0040
# Epoch 7/50
# 180/180 - 1s - 5ms/step - loss: 0.0332 - val_loss: 0.0039
# Epoch 8/50
# 180/180 - 1s - 4ms/step - loss: 0.0332 - val_loss: 0.0039
# Epoch 9/50
# 180/180 - 1s - 4ms/step - loss: 0.0332 - val_loss: 0.0038
# Epoch 10/50
# 180/180 - 1s - 4ms/step - loss: 0.0331 - val_loss: 0.0037
# Epoch 11/50
# 180/180 - 1s - 5ms/step - loss: 0.0331 - val_loss: 0.0037
# Epoch 12/50
# 180/180 - 1s - 7ms/step - loss: 0.0331 - val_loss: 0.0036
# Epoch 13/50
# 180/180 - 1s - 4ms/step - loss: 0.0331 - val_loss: 0.0036
# Epoch 14/50
# 180/180 - 1s - 4ms/step - loss: 0.0331 - val_loss: 0.0035
# Epoch 15/50
# 180/180 - 1s - 4ms/step - loss: 0.0331 - val_loss: 0.0035
# Epoch 16/50
# 180/180 - 1s - 4ms/step - loss: 0.0331 - val_loss: 0.0034
# Epoch 17/50
# 180/180 - 1s - 4ms/step - loss: 0.0331 - val_loss: 0.0034
# Epoch 18/50
# 180/180 - 1s - 4ms/step - loss: 0.0330 - val_loss: 0.0034
# Epoch 19/50
# 180/180 - 1s - 4ms/step - loss: 0.0330 - val_loss: 0.0033
# Epoch 20/50
# 180/180 - 1s - 4ms/step - loss: 0.0330 - val_loss: 0.0033
# Epoch 21/50
# 180/180 - 1s - 4ms/step - loss: 0.0330 - val_loss: 0.0033
# Epoch 22/50
# 180/180 - 1s - 4ms/step - loss: 0.0330 - val_loss: 0.0032
# Epoch 23/50
# 180/180 - 1s - 4ms/step - loss: 0.0330 - val_loss: 0.0032
# Epoch 24/50
# 180/180 - 1s - 4ms/step - loss: 0.0330 - val_loss: 0.0032
# Epoch 25/50
# 180/180 - 1s - 8ms/step - loss: 0.0330 - val_loss: 0.0032
# Epoch 26/50
# 180/180 - 1s - 7ms/step - loss: 0.0329 - val_loss: 0.0031
# Epoch 27/50
# 180/180 - 1s - 4ms/step - loss: 0.0329 - val_loss: 0.0031
# Epoch 28/50
# 180/180 - 1s - 4ms/step - loss: 0.0329 - val_loss: 0.0031
# Epoch 29/50
# 180/180 - 1s - 5ms/step - loss: 0.0329 - val_loss: 0.0031
# Epoch 30/50
# 180/180 - 1s - 4ms/step - loss: 0.0329 - val_loss: 0.0031
# Epoch 31/50
# 180/180 - 1s - 4ms/step - loss: 0.0328 - val_loss: 0.0031
# Epoch 32/50
# 180/180 - 1s - 4ms/step - loss: 0.0328 - val_loss: 0.0031
# Epoch 33/50
# 180/180 - 1s - 4ms/step - loss: 0.0328 - val_loss: 0.0031
# Epoch 34/50
# 180/180 - 1s - 4ms/step - loss: 0.0328 - val_loss: 0.0031
# Epoch 35/50
# 180/180 - 1s - 4ms/step - loss: 0.0328 - val_loss: 0.0031
# Epoch 36/50
# 180/180 - 1s - 4ms/step - loss: 0.0328 - val_loss: 0.0031
# Epoch 37/50
# 180/180 - 1s - 4ms/step - loss: 0.0327 - val_loss: 0.0032
# Epoch 38/50
# 180/180 - 1s - 6ms/step - loss: 0.0327 - val_loss: 0.0032
# Epoch 39/50
# 180/180 - 1s - 5ms/step - loss: 0.0327 - val_loss: 0.0032
# Epoch 40/50
# 180/180 - 1s - 5ms/step - loss: 0.0327 - val_loss: 0.0032
# Epoch 41/50
# 180/180 - 1s - 5ms/step - loss: 0.0327 - val_loss: 0.0032
# Epoch 42/50
# 180/180 - 1s - 4ms/step - loss: 0.0327 - val_loss: 0.0032
# Epoch 43/50
# 180/180 - 1s - 4ms/step - loss: 0.0327 - val_loss: 0.0032
# Epoch 44/50
# 180/180 - 1s - 5ms/step - loss: 0.0327 - val_loss: 0.0032
# Epoch 45/50
# 180/180 - 1s - 4ms/step - loss: 0.0326 - val_loss: 0.0032
# Epoch 46/50
# 180/180 - 1s - 4ms/step - loss: 0.0326 - val_loss: 0.0032
# Epoch 47/50
# 180/180 - 1s - 4ms/step - loss: 0.0326 - val_loss: 0.0032
# Epoch 48/50
# 180/180 - 1s - 4ms/step - loss: 0.0326 - val_loss: 0.0032
# Epoch 49/50
# 180/180 - 1s - 4ms/step - loss: 0.0326 - val_loss: 0.0031
# Epoch 50/50
# 180/180 - 1s - 4ms/step - loss: 0.0326 - val_loss: 0.0031

# %%
import numpy as np
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# Predict
y_pred = model.predict(X_test)

# Inverse scaling (if needed)
#y_test_inv = scaler.inverse_transform(np.concatenate((X_test.reshape(X_test.shape[0], X_test.shape[2]), y_test), axis=1))[:, -3:]
#y_pred_inv = scaler.inverse_transform(np.concatenate((X_test.reshape(X_test.shape[0], X_test.shape[2]), y_pred), axis=1))[:, -3:]

# Evaluate
rmse_cpu = np.sqrt(mean_squared_error(y_test[:, 0], y_pred[:, 0]))
rmse_memory = np.sqrt(mean_squared_error(y_test[:, 1], y_pred[:, 1]))
rmse_sci_e = np.sqrt(mean_squared_error(y_test[:, 2], y_pred[:, 2]))
print(f'RMSE (CPU): {rmse_cpu}')
print(f'RMSE (Memory): {rmse_memory}')
print(f'RMSE (SCI-E): {rmse_sci_e}')

# Plot predictions
plt.figure(figsize=(14, 8))
plt.plot(y_test[:, 0], label='Actual CPU')
plt.plot(y_pred[:, 0], label='Predicted CPU')
plt.legend()
plt.show()

plt.figure(figsize=(14, 8))
plt.plot(y_test[:, 1], label='Actual Memory')
plt.plot(y_pred[:, 1], label='Predicted Memory')
plt.legend()
plt.show()

plt.figure(figsize=(14, 8))
plt.plot(y_test[:, 2], label='Actual SCI-E')
plt.plot(y_pred[:, 2], label='Predicted SCI-E')
plt.legend()
plt.show()
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# RMSE (CPU): 0.08649345925810059
# RMSE (Memory): 0.030446713947523123
# RMSE (SCI-E): 0.031980573256487926
